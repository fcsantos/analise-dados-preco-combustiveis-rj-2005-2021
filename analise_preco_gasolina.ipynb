# %% [markdown]
# # Análise variação do preço da gasolina
#
# **Objetivo da análise**
#
# Gerar uma tabela com a variação percentural ano a ano do preço médio da gasolina comum no estado do Rio de Janeiro.
#
# **Base de Dados no Kaggle**
#
# [https://www.kaggle.com/datasets/matheusfreitag/gas-prices-in-brazil](https://www.kaggle.com/datasets/matheusfreitag/gas-prices-in-brazil)

# %% [markdown]
# # Carregando bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Carregando a base de Dados

# %%
df = pd.read_csv('precos.tsv', sep='\t', parse_dates=['DATA INICIAL', 'DATA FINAL' ])

# %%
df.head()
# Out:
#   DATA INICIAL DATA FINAL        REGIÃO              ESTADO           PRODUTO  \
# 0   2004-05-09 2004-05-15  CENTRO OESTE    DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09 2004-05-15  CENTRO OESTE               GOIAS  ETANOL HIDRATADO
# 2   2004-05-09 2004-05-15  CENTRO OESTE         MATO GROSSO  ETANOL HIDRATADO
# 3   2004-05-09 2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL  ETANOL HIDRATADO
# 4   2004-05-09 2004-05-15      NORDESTE             ALAGOAS  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
# 3                           162              R$/l                1.262
# 4                           103              R$/l                1.181
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.016                  1.19                 1.350
# 1                  0.114                  0.89                 1.449
# 2                  0.097                  1.18                 1.760
# 3                  0.070                  1.09                 1.509
# 4                  0.078                  1.05                 1.400
#
#   MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                0.463                     0.012                    0.825
# 1                0.399                     0.098                    0.763
# 2                0.419                     0.070                     0.97
# 3                0.432                     0.055                     0.83
# 4                 0.24                     0.066                    0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                    0.9666                         0.133
# 1                      1.05                         0.115
# 2                     1.161                         0.098
# 3                   1.22242                         0.143
# 4                    1.0317                         0.082

# %%
df.tail()
# Out:
#        DATA INICIAL DATA FINAL    REGIÃO          ESTADO          PRODUTO  \
# 120818   2021-04-25 2021-05-01     NORTE         RORAIMA  OLEO DIESEL S10
# 120819   2021-04-25 2021-05-01       SUL  SANTA CATARINA  OLEO DIESEL S10
# 120820   2021-04-25 2021-05-01   SUDESTE       SAO PAULO  OLEO DIESEL S10
# 120821   2021-04-25 2021-05-01  NORDESTE         SERGIPE  OLEO DIESEL S10
# 120822   2021-04-25 2021-05-01     NORTE       TOCANTINS  OLEO DIESEL S10
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 120818                            12              R$/l                4.582
# 120819                           100              R$/l                4.141
# 120820                           886              R$/l                4.246
# 120821                            33              R$/l                4.464
# 120822                            18              R$/l                4.352
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 120818                  0.056                 4.510                 4.690
# 120819                  0.187                 3.838                 4.739
# 120820                  0.216                 3.769                 5.199
# 120821                  0.205                 4.190                 4.699
# 120822                  0.156                 4.199                 4.699
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 120818             -99999.0                     0.012
# 120819             -99999.0                     0.045
# 120820             -99999.0                     0.051
# 120821             -99999.0                     0.046
# 120822             -99999.0                     0.036
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 120818                 -99999.0                   -99999.0
# 120819                 -99999.0                   -99999.0
# 120820                 -99999.0                   -99999.0
# 120821                 -99999.0                   -99999.0
# 120822                 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 120818                  -99999.0                  -99999.0
# 120819                  -99999.0                  -99999.0
# 120820                  -99999.0                  -99999.0
# 120821                  -99999.0                  -99999.0
# 120822                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 120818                      -99999.0
# 120819                      -99999.0
# 120820                      -99999.0
# 120821                      -99999.0
# 120822                      -99999.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120823 entries, 0 to 120822
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   120823 non-null  datetime64[ns]
#  1   DATA FINAL                     120823 non-null  datetime64[ns]
#  2   REGIÃO                         120823 non-null  object
#  3   ESTADO                         120823 non-null  object
#  4   PRODUTO                        120823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   120823 non-null  int64
#  6   UNIDADE DE MEDIDA              120823 non-null  object
#  7   PREÇO MÉDIO REVENDA            120823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          120823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           120823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           120823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           120823 non-null  object
#  12  COEF DE VARIAÇÃO REVENDA       120823 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       120823 non-null  object
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     120823 non-null  object
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      120823 non-null  object
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      120823 non-null  object
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  120823 non-null  object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(10)
# memory usage: 16.6+ MB

# %%
df.head()
# Out:
#   DATA INICIAL DATA FINAL        REGIÃO              ESTADO           PRODUTO  \
# 0   2004-05-09 2004-05-15  CENTRO OESTE    DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09 2004-05-15  CENTRO OESTE               GOIAS  ETANOL HIDRATADO
# 2   2004-05-09 2004-05-15  CENTRO OESTE         MATO GROSSO  ETANOL HIDRATADO
# 3   2004-05-09 2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL  ETANOL HIDRATADO
# 4   2004-05-09 2004-05-15      NORDESTE             ALAGOAS  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
# 3                           162              R$/l                1.262
# 4                           103              R$/l                1.181
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.016                  1.19                 1.350
# 1                  0.114                  0.89                 1.449
# 2                  0.097                  1.18                 1.760
# 3                  0.070                  1.09                 1.509
# 4                  0.078                  1.05                 1.400
#
#   MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                0.463                     0.012                    0.825
# 1                0.399                     0.098                    0.763
# 2                0.419                     0.070                     0.97
# 3                0.432                     0.055                     0.83
# 4                 0.24                     0.066                    0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                    0.9666                         0.133
# 1                      1.05                         0.115
# 2                     1.161                         0.098
# 3                   1.22242                         0.143
# 4                    1.0317                         0.082

# %%
df_tratado = df.loc[:, :'PREÇO MÁXIMO REVENDA'].copy()

# %%
df_tratado.columns
# Out:
# Index(['dt_inicial', 'dt_final', 'regiao', 'estado', 'produto',
#        'nr_postos_pesquisados', 'unidade_medida', 'preco_medio_revenda',
#        'std_revenda', 'preco_min_revenda', 'preco_max_revenda'],
#       dtype='object')

# %%
df_tratado.columns = ['dt_inicial', 'dt_final', 'regiao', 'estado', 'produto',
       'nr_postos_pesquisados', 'unidade_medida',
       'preco_medio_revenda', 'std_revenda', 'preco_min_revenda',
       'preco_max_revenda']

# %%
df_tratado.head()
# Out:
#   dt_inicial   dt_final        regiao              estado           produto  \
# 0 2004-05-09 2004-05-15  CENTRO OESTE    DISTRITO FEDERAL  ETANOL HIDRATADO
# 1 2004-05-09 2004-05-15  CENTRO OESTE               GOIAS  ETANOL HIDRATADO
# 2 2004-05-09 2004-05-15  CENTRO OESTE         MATO GROSSO  ETANOL HIDRATADO
# 3 2004-05-09 2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL  ETANOL HIDRATADO
# 4 2004-05-09 2004-05-15      NORDESTE             ALAGOAS  ETANOL HIDRATADO
#
#    nr_postos_pesquisados unidade_medida  preco_medio_revenda  std_revenda  \
# 0                    127           R$/l                1.288        0.016
# 1                    387           R$/l                1.162        0.114
# 2                    192           R$/l                1.389        0.097
# 3                    162           R$/l                1.262        0.070
# 4                    103           R$/l                1.181        0.078
#
#    preco_min_revenda  preco_max_revenda
# 0               1.19              1.350
# 1               0.89              1.449
# 2               1.18              1.760
# 3               1.09              1.509
# 4               1.05              1.400

# %% [markdown]
# # Análises exploratórias iniciais

# %%
df_tratado.head()
# Out:
#   dt_inicial   dt_final        regiao              estado           produto  \
# 0 2004-05-09 2004-05-15  CENTRO OESTE    DISTRITO FEDERAL  ETANOL HIDRATADO
# 1 2004-05-09 2004-05-15  CENTRO OESTE               GOIAS  ETANOL HIDRATADO
# 2 2004-05-09 2004-05-15  CENTRO OESTE         MATO GROSSO  ETANOL HIDRATADO
# 3 2004-05-09 2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL  ETANOL HIDRATADO
# 4 2004-05-09 2004-05-15      NORDESTE             ALAGOAS  ETANOL HIDRATADO
#
#    nr_postos_pesquisados unidade_medida  preco_medio_revenda  std_revenda  \
# 0                    127           R$/l                1.288        0.016
# 1                    387           R$/l                1.162        0.114
# 2                    192           R$/l                1.389        0.097
# 3                    162           R$/l                1.262        0.070
# 4                    103           R$/l                1.181        0.078
#
#    preco_min_revenda  preco_max_revenda
# 0               1.19              1.350
# 1               0.89              1.449
# 2               1.18              1.760
# 3               1.09              1.509
# 4               1.05              1.400

# %%
# verificando o numero de linhas e colunas do dataframe
df.shape
# Out:
# (120823, 18)

# %%
# verificando a quantidade de estados
len(df_tratado['estado'].unique())
# Out:
# 27

# %%
df_tratado['estado'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
df_tratado['produto'].unique()
# Out:
# array(['ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL',
#        'ÓLEO DIESEL S10', 'OLEO DIESEL', 'OLEO DIESEL S10',
#        'GASOLINA ADITIVADA'], dtype=object)

# %%
df_tratado['dt_final'].max()
# Out:
# Timestamp('2021-05-01 00:00:00')

# %% [markdown]
# # Filtrando o dataset

# %%
df_rio_gasolina = df_tratado.query("estado == 'RIO DE JANEIRO' and produto == 'GASOLINA COMUM'").copy()

# %%
df_rio_gasolina.shape
# Out:
# (873, 11)

# %%
df_rio_gasolina.head()
# Out:
#       dt_inicial   dt_final   regiao          estado         produto  \
# 12086 2004-05-09 2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113 2004-05-16 2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140 2004-05-23 2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167 2004-05-30 2004-06-05  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194 2004-06-06 2004-06-12  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
#
#        nr_postos_pesquisados unidade_medida  preco_medio_revenda  std_revenda  \
# 12086                   1071           R$/l                2.045        0.109
# 12113                   1055           R$/l                2.040        0.113
# 12140                   1091           R$/l                2.042        0.108
# 12167                   1055           R$/l                2.053        0.111
# 12194                   1091           R$/l                2.063        0.107
#
#        preco_min_revenda  preco_max_revenda
# 12086               1.70              2.599
# 12113               1.70              2.599
# 12140               1.70              2.599
# 12167               1.73              2.599
# 12194               1.76              2.599

# %% [markdown]
# # Configurando o índice do DataFrame df_rio_gasolina

# %%
df_rio_gasolina.set_index('dt_final', inplace=True)

# %%
df_rio_gasolina.head()
# Out:
#            dt_inicial   regiao          estado         produto  \
# dt_final
# 2004-05-15 2004-05-09  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 2004-05-22 2004-05-16  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 2004-05-29 2004-05-23  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 2004-06-05 2004-05-30  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 2004-06-12 2004-06-06  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
#
#             nr_postos_pesquisados unidade_medida  preco_medio_revenda  \
# dt_final
# 2004-05-15                   1071           R$/l                2.045
# 2004-05-22                   1055           R$/l                2.040
# 2004-05-29                   1091           R$/l                2.042
# 2004-06-05                   1055           R$/l                2.053
# 2004-06-12                   1091           R$/l                2.063
#
#             std_revenda  preco_min_revenda  preco_max_revenda
# dt_final
# 2004-05-15        0.109               1.70              2.599
# 2004-05-22        0.113               1.70              2.599
# 2004-05-29        0.108               1.70              2.599
# 2004-06-05        0.111               1.73              2.599
# 2004-06-12        0.107               1.76              2.599

# %%
# verificando anos e meses no dataset
datas = []
for i in df_rio_gasolina.index:
    datas.append((i.year, i.month))

# %%
# removendo dados duplicados do dataset
# nao é a melhor forma de fazer isso
set(datas)
# Out:
# {(2004, 5),
#  (2004, 6),
#  (2004, 7),
#  (2004, 8),
#  (2004, 9),
#  (2004, 10),
#  (2004, 11),
#  (2004, 12),
#  (2005, 1),
#  (2005, 2),
#  (2005, 3),
#  (2005, 4),
#  (2005, 5),
#  (2005, 6),
#  (2005, 7),
#  (2005, 8),
#  (2005, 9),
#  (2005, 10),
#  (2005, 11),
#  (2005, 12),
#  (2006, 1),
#  (2006, 2),
#  (2006, 3),
#  (2006, 4),
#  (2006, 5),
#  (2006, 6),
#  (2006, 7),
#  (2006, 8),
#  (2006, 9),
#  (2006, 10),
#  (2006, 11),
#  (2006, 12),
#  (2007, 1),
#  (2007, 2),
#  (2007, 3),
#  (2007, 4),
#  (2007, 5),
#  (2007, 6),
#  (2007, 7),
#  (2007, 8),
#  (2007, 9),
#  (2007, 10),
#  (2007, 11),
#  (2007, 12),
#  (2008, 1),
#  (2008, 2),
#  (2008, 3),
#  (2008, 4),
#  (2008, 5),
#  (2008, 6),
#  (2008, 7),
#  (2008, 8),
#  (2008, 9),
#  (2008, 10),
#  (2008, 11),
#  (2008, 12),
#  (2009, 1),
#  (2009, 2),
#  (2009, 3),
#  (2009, 4),
#  (2009, 5),
#  (2009, 6),
#  (2009, 7),
#  (2009, 8),
#  (2009, 9),
#  (2009, 10),
#  (2009, 11),
#  (2009, 12),
#  (2010, 1),
#  (2010, 2),
#  (2010, 3),
#  (2010, 4),
#  (2010, 5),
#  (2010, 6),
#  (2010, 7),
#  (2010, 8),
#  (2010, 9),
#  (2010, 10),
#  (2010, 11),
#  (2010, 12),
#  (2011, 1),
#  (2011, 2),
#  (2011, 3),
#  (2011, 4),
#  (2011, 5),
#  (2011, 6),
#  (2011, 7),
#  (2011, 8),
#  (2011, 9),
#  (2011, 10),
#  (2011, 11),
#  (2011, 12),
#  (2012, 1),
#  (2012, 2),
#  (2012, 3),
#  (2012, 4),
#  (2012, 5),
#  (2012, 6),
#  (2012, 7),
#  (2012, 8),
#  (2012, 9),
#  (2012, 10),
#  (2012, 11),
#  (2012, 12),
#  (2013, 1),
#  (2013, 2),
#  (2013, 3),
#  (2013, 4),
#  (2013, 5),
#  (2013, 6),
#  (2013, 7),
#  (2013, 8),
#  (2013, 9),
#  (2013, 10),
#  (2013, 11),
#  (2013, 12),
#  (2014, 1),
#  (2014, 2),
#  (2014, 3),
#  (2014, 4),
#  (2014, 5),
#  (2014, 6),
#  (2014, 7),
#  (2014, 8),
#  (2014, 9),
#  (2014, 10),
#  (2014, 11),
#  (2014, 12),
#  (2015, 1),
#  (2015, 2),
#  (2015, 3),
#  (2015, 4),
#  (2015, 5),
#  (2015, 6),
#  (2015, 7),
#  (2015, 8),
#  (2015, 9),
#  (2015, 10),
#  (2015, 11),
#  (2015, 12),
#  (2016, 1),
#  (2016, 2),
#  (2016, 3),
#  (2016, 4),
#  (2016, 5),
#  (2016, 6),
#  (2016, 7),
#  (2016, 8),
#  (2016, 9),
#  (2016, 10),
#  (2016, 11),
#  (2016, 12),
#  (2017, 1),
#  (2017, 2),
#  (2017, 3),
#  (2017, 4),
#  (2017, 5),
#  (2017, 6),
#  (2017, 7),
#  (2017, 8),
#  (2017, 9),
#  (2017, 10),
#  (2017, 11),
#  (2017, 12),
#  (2018, 1),
#  (2018, 2),
#  (2018, 3),
#  (2018, 4),
#  (2018, 5),
#  (2018, 6),
#  (2018, 7),
#  (2018, 8),
#  (2018, 9),
#  (2018, 10),
#  (2018, 11),
#  (2018, 12),
#  (2019, 1),
#  (2019, 2),
#  (2019, 3),
#  (2019, 4),
#  (2019, 5),
#  (2019, 6),
#  (2019, 7),
#  (2019, 8),
#  (2019, 9),
#  (2019, 10),
#  (2019, 11),
#  (2019, 12),
#  (2020, 1),
#  (2020, 2),
#  (2020, 3),
#  (2020, 4),
#  (2020, 5),
#  (2020, 6),
#  (2020, 7),
#  (2020, 8),
#  (2020, 10),
#  (2020, 11),
#  (2020, 12),
#  (2021, 1),
#  (2021, 2),
#  (2021, 3),
#  (2021, 4),
#  (2021, 5)}

# %%
df_rio_gasolina = df_rio_gasolina.loc['2005':'2020'].copy()

# %%
df_rio_gasolina.shape
# Out:
# (822, 10)

# %% [markdown]
# # Estatísticas básicas

# %%
plt.figure(figsize=(15,5))
df_rio_gasolina['preco_medio_revenda'].hist()
plt.savefig('histograma.png')

# %%
sns.set_style('darkgrid')

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data=df_rio_gasolina, x ='preco_medio_revenda' )
plt.savefig('boxplot.png')

# %%
df_rio_gasolina['preco_medio_revenda'].describe()
# Out:
# count    822.000000
# mean       3.303408
# std        0.871114
# min        2.247000
# 25%        2.559250
# 50%        2.903000
# 75%        3.942250
# max        5.119000
# Name: preco_medio_revenda, dtype: float64

# %% [markdown]
# # Gerando a tabela de variação percentual

# %%
df_rio_gasolina.head()
# Out:
#            dt_inicial   regiao          estado         produto  \
# dt_final
# 2005-01-01 2004-12-26  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 2005-01-08 2005-01-02  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 2005-01-15 2005-01-09  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 2005-01-22 2005-01-16  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 2005-01-29 2005-01-23  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
#
#             nr_postos_pesquisados unidade_medida  preco_medio_revenda  \
# dt_final
# 2005-01-01                   1066           R$/l                2.293
# 2005-01-08                   1096           R$/l                2.297
# 2005-01-15                   1069           R$/l                2.292
# 2005-01-22                   1094           R$/l                2.296
# 2005-01-29                   1073           R$/l                2.290
#
#             std_revenda  preco_min_revenda  preco_max_revenda
# dt_final
# 2005-01-01        0.101              2.050              2.749
# 2005-01-08        0.098              1.990              2.749
# 2005-01-15        0.101              2.039              2.749
# 2005-01-22        0.099              2.000              2.749
# 2005-01-29        0.103              2.009              2.749

# %%
df_tabela = df_rio_gasolina.groupby(df_rio_gasolina.index.year).agg({
    'preco_medio_revenda': np.mean
})
# Out:
# C:\Users\felip\AppData\Local\Temp\ipykernel_55920\4186596487.py:1: FutureWarning: The provided callable <function mean at 0x0000024CAFE05BC0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df_tabela = df_rio_gasolina.groupby(df_rio_gasolina.index.year).agg({

# %%
df_tabela
# Out:
#           preco_medio_revenda
# dt_final
# 2005                 2.338588
# 2006                 2.561365
# 2007                 2.532077
# 2008                 2.546731
# 2009                 2.564980
# 2010                 2.647788
# 2011                 2.832698
# 2012                 2.852827
# 2013                 2.995442
# 2014                 3.132115
# 2015                 3.537471
# 2016                 3.917736
# 2017                 4.102308
# 2018                 4.855077
# 2019                 4.855096
# 2020                 4.761295

# %%
df_tabela.shift(1)
# Out:
#           preco_medio_revenda
# dt_final
# 2005                      NaN
# 2006                 2.338588
# 2007                 2.561365
# 2008                 2.532077
# 2009                 2.546731
# 2010                 2.564980
# 2011                 2.647788
# 2012                 2.832698
# 2013                 2.852827
# 2014                 2.995442
# 2015                 3.132115
# 2016                 3.537471
# 2017                 3.917736
# 2018                 4.102308
# 2019                 4.855077
# 2020                 4.855096

# %%
df_tabela['valor_ano_anterior'] = df_tabela.shift(1)

# %%
df_tabela = df_tabela.loc['2006':].copy()

# %%
df_tabela['variacao_percentual'] = round(((df_tabela['preco_medio_revenda'] / df_tabela['valor_ano_anterior']) - 1) * 100,2)

# %%
df_tabela
# Out:
#           preco_medio_revenda  valor_ano_anterior  variacao_percentual
# dt_final
# 2006                 2.561365            2.338588                 9.53
# 2007                 2.532077            2.561365                -1.14
# 2008                 2.546731            2.532077                 0.58
# 2009                 2.564980            2.546731                 0.72
# 2010                 2.647788            2.564980                 3.23
# 2011                 2.832698            2.647788                 6.98
# 2012                 2.852827            2.832698                 0.71
# 2013                 2.995442            2.852827                 5.00
# 2014                 3.132115            2.995442                 4.56
# 2015                 3.537471            3.132115                12.94
# 2016                 3.917736            3.537471                10.75
# 2017                 4.102308            3.917736                 4.71
# 2018                 4.855077            4.102308                18.35
# 2019                 4.855096            4.855077                 0.00
# 2020                 4.761295            4.855096                -1.93

# %%
df_tabela.to_excel('tabela_variacao_gasolina_rj.xlsx')
